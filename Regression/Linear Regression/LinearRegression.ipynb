# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('House Price Prediction Dataset (1).csv')
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
df.drop("Id", axis=1, inplace=True)
df
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0     1360         5          4       3       1970  Downtown  Excellent
# 1     4272         5          4       3       1958  Downtown  Excellent
# 2     3592         2          2       3       1938  Downtown       Good
# 3      966         4          2       2       1902  Suburban       Fair
# 4     4926         1          4       2       1975  Downtown       Fair
# ...    ...       ...        ...     ...        ...       ...        ...
# 1995  4994         5          4       3       1923  Suburban       Poor
# 1996  3046         5          2       1       2019  Suburban       Poor
# 1997  1062         5          1       2       1903     Rural       Poor
# 1998  4062         3          1       2       1936     Urban  Excellent
# 1999  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# 0        No  149919
# 1        No  424998
# 2        No  266746
# ...

# %%
Le = LabelEncoder()

df['Location'] = Le.fit_transform(df['Location'])
df['Condition'] = Le.fit_transform(df['Condition'])
df['Garage'] = Le.fit_transform(df['Garage'])

# %%
df
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0     1360         5          4       3       1970         0          0
# 1     4272         5          4       3       1958         0          0
# 2     3592         2          2       3       1938         0          2
# 3      966         4          2       2       1902         2          1
# 4     4926         1          4       2       1975         0          1
# ...    ...       ...        ...     ...        ...       ...        ...
# 1995  4994         5          4       3       1923         2          3
# 1996  3046         5          2       1       2019         2          3
# 1997  1062         5          1       2       1903         1          3
# 1998  4062         3          1       2       1936         3          0
# 1999  2989         5          1       3       1903         2          1
#
#       Garage   Price
# 0          0  149919
# 1          0  424998
# 2          0  266746
# ...

# %%
for column in ['YearBuilt']:
    df[column] = 2024 - df[column];
    
df['YearBuilt']
# Out:
# 0        54
# 1        66
# 2        86
# 3       122
# 4        49
#        ...
# 1995    101
# 1996      5
# 1997    121
# 1998     88
# 1999    121
# Name: YearBuilt, Length: 2000, dtype: int64

# %%
df
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0     1360         5          4       3         54         0          0
# 1     4272         5          4       3         66         0          0
# 2     3592         2          2       3         86         0          2
# 3      966         4          2       2        122         2          1
# 4     4926         1          4       2         49         0          1
# ...    ...       ...        ...     ...        ...       ...        ...
# 1995  4994         5          4       3        101         2          3
# 1996  3046         5          2       1          5         2          3
# 1997  1062         5          1       2        121         1          3
# 1998  4062         3          1       2         88         3          0
# 1999  2989         5          1       3        121         2          1
#
#       Garage   Price
# 0          0  149919
# 1          0  424998
# 2          0  266746
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# Apply scaler to multiple columns at once
columns_to_scale = ['Area', 'YearBuilt', 'Price']
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# %%
df
# Out:
#           Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0     0.183220         5          4       3   0.430894         0          0
# 1     0.837138         5          4       3   0.528455         0          0
# 2     0.677360         2          2       3   0.691057         0          2
# 3     0.096854         4          2       2   0.983740         2          1
# 4     0.977791         1          4       2   0.390244         0          1
# ...        ...       ...        ...     ...        ...       ...        ...
# 1995  0.997532         5          4       3   0.813008         2          3
# 1996  0.552128         5          2       1   0.032520         2          3
# 1997  0.117212         5          1       2   0.975610         1          3
# 1998  0.785935         3          1       2   0.707317         3          0
# 1999  0.537940         5          1       3   0.975610         2          1
#
#       Garage     Price
# 0          0  0.097598
# ...

# %%
x = df.iloc[ : , :-1]
y = df.iloc[ : ,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#           Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1793  0.613819         4          1       3   0.910569         2          0
# 64    0.842073         5          3       2   0.170732         0          1
# 1981  0.790253         5          4       2   0.308943         1          0
# 852   0.071561         4          1       3   0.772358         2          0
# 803   0.481801         3          1       1   0.569106         0          0
# ...        ...       ...        ...     ...        ...       ...        ...
# 1798  0.320790         2          1       1   0.918699         3          1
# 902   0.088834         3          2       2   0.837398         2          0
# 1819  0.048118         2          3       2   0.658537         1          2
# 1857  0.709439         4          2       2   0.032520         0          3
# 1661  0.734115         4          4       1   0.796748         1          2
#
#       Garage
# 1793       1
# 64         1
# ...

# %%
[500, 2, 2, 1, 16, 3, 2, 0]
# Out:
# [500, 2, 2, 1, 16, 3, 2, 0]

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

mse, r2
# Out:
# (np.float64(0.08240517311031546), -0.0403745529671804)
