# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('Disease_symptom_and_patient_profile_dataset.csv')
df
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# 1           Normal            Normal         Negative
# 2           Normal            Normal         Negative
# 3           Normal            Normal         Positive
# 4           Normal            Normal         Positive
# ..             ...               ...              ...
# 344           High              High         Positive
# 345           High              High         Positive
# 346           High              High         Positive
# 347           High              High         Positive
# 348           High              High         Positive
#
# [349 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Disease               349 non-null    object
#  1   Fever                 349 non-null    object
#  2   Cough                 349 non-null    object
#  3   Fatigue               349 non-null    object
#  4   Difficulty Breathing  349 non-null    object
#  5   Age                   349 non-null    int64
#  6   Gender                349 non-null    object
#  7   Blood Pressure        349 non-null    object
#  8   Cholesterol Level     349 non-null    object
#  9   Outcome Variable      349 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 27.4+ KB

# %%
le = LabelEncoder()

for column in ['Disease','Fever','Cough','Fatigue','Difficulty Breathing','Gender','Blood Pressure','Cholesterol Level','Outcome Variable']:
    df[column] = le.fit_transform(df[column])

# %%
df
# Out:
#      Disease  Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  \
# 0         56      1      0        1                     1   19       0
# 1         24      0      1        1                     0   25       0
# 2         37      0      1        1                     0   25       0
# 3          6      1      1        0                     1   25       1
# 4          6      1      1        0                     1   25       1
# ..       ...    ...    ...      ...                   ...  ...     ...
# 344      101      1      0        1                     0   80       0
# 345      101      1      0        1                     0   85       1
# 346      101      1      0        1                     0   85       1
# 347      101      1      0        1                     0   90       0
# 348      101      1      0        1                     0   90       0
#
#      Blood Pressure  Cholesterol Level  Outcome Variable
# 0                 1                  2                 1
# 1                 2                  2                 0
# 2                 2                  2                 0
# 3                 2                  2                 1
# 4                 2                  2                 1
# ..              ...                ...               ...
# 344               0                  0                 1
# 345               0                  0                 1
# 346               0                  0                 1
# 347               0                  0                 1
# 348               0                  0                 1
#
# [349 rows x 10 columns]

# %%
scaler = MinMaxScaler()

# Apply scaler to multiple columns at once
columns_to_scale = ['Age']
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# %%
df
# Out:
#      Disease  Fever  Cough  Fatigue  Difficulty Breathing       Age  Gender  \
# 0         56      1      0        1                     1  0.000000       0
# 1         24      0      1        1                     0  0.084507       0
# 2         37      0      1        1                     0  0.084507       0
# 3          6      1      1        0                     1  0.084507       1
# 4          6      1      1        0                     1  0.084507       1
# ..       ...    ...    ...      ...                   ...       ...     ...
# 344      101      1      0        1                     0  0.859155       0
# 345      101      1      0        1                     0  0.929577       1
# 346      101      1      0        1                     0  0.929577       1
# 347      101      1      0        1                     0  1.000000       0
# 348      101      1      0        1                     0  1.000000       0
#
#      Blood Pressure  Cholesterol Level  Outcome Variable
# 0                 1                  2                 1
# 1                 2                  2                 0
# 2                 2                  2                 0
# 3                 2                  2                 1
# 4                 2                  2                 1
# ..              ...                ...               ...
# 344               0                  0                 1
# 345               0                  0                 1
# 346               0                  0                 1
# 347               0                  0                 1
# 348               0                  0                 1
#
# [349 rows x 10 columns]

# %%
x = df.iloc[ : , 1:-1]
y = df.iloc[ : ,-1]

x, y
# Out:
# (     Fever  Cough  Fatigue  Difficulty Breathing       Age  Gender  \
#  0        1      0        1                     1  0.000000       0
#  1        0      1        1                     0  0.084507       0
#  2        0      1        1                     0  0.084507       0
#  3        1      1        0                     1  0.084507       1
#  4        1      1        0                     1  0.084507       1
#  ..     ...    ...      ...                   ...       ...     ...
#  344      1      0        1                     0  0.859155       0
#  345      1      0        1                     0  0.929577       1
#  346      1      0        1                     0  0.929577       1
#  347      1      0        1                     0  1.000000       0
#  348      1      0        1                     0  1.000000       0
#
#       Blood Pressure  Cholesterol Level
#  0                 1                  2
#  1                 2                  2
#  2                 2                  2
#  3                 2                  2
#  4                 2                  2
#  ..              ...                ...
#  344               0                  0
#  345               0                  0
#  346               0                  0
#  347               0                  0
#  348               0                  0
#
#  [349 rows x 8 columns],
#  0      1
#  1      0
#  2      0
#  3      1
#  4      1
#        ..
#  344    1
#  345    1
#  346    1
#  347    1
#  348    1
#  Name: Outcome Variable, Length: 349, dtype: int64)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=False)

x_train, x_test, y_train, y_test
# Out:
# (     Fever  Cough  Fatigue  Difficulty Breathing       Age  Gender  \
#  0        1      0        1                     1  0.000000       0
#  1        0      1        1                     0  0.084507       0
#  2        0      1        1                     0  0.084507       0
#  3        1      1        0                     1  0.084507       1
#  4        1      1        0                     1  0.084507       1
#  ..     ...    ...      ...                   ...       ...     ...
#  274      0      0        1                     0  0.577465       1
#  275      1      1        0                     0  0.577465       1
#  276      1      1        0                     0  0.577465       1
#  277      0      0        1                     0  0.577465       1
#  278      1      1        0                     0  0.577465       0
#
#       Blood Pressure  Cholesterol Level
#  0                 1                  2
#  1                 2                  2
#  2                 2                  2
#  3                 2                  2
#  4                 2                  2
#  ..              ...                ...
#  274               0                  0
#  275               0                  0
#  276               0                  0
#  277               2                  2
#  278               0                  2
#
#  [279 rows x 8 columns],
#       Fever  Cough  Fatigue  Difficulty Breathing       Age  Gender  \
#  279      1      1        0                     0  0.577465       0
#  280      0      1        0                     1  0.577465       0
#  281      0      0        1                     0  0.577465       1
#  282      1      0        0                     0  0.577465       1
#  283      0      1        0                     0  0.577465       1
#  ..     ...    ...      ...                   ...       ...     ...
#  344      1      0        1                     0  0.859155       0
#  345      1      0        1                     0  0.929577       1
#  346      1      0        1                     0  0.929577       1
#  347      1      0        1                     0  1.000000       0
#  348      1      0        1                     0  1.000000       0
#
#       Blood Pressure  Cholesterol Level
#  279               0                  2
#  280               2                  2
#  281               2                  2
#  282               0                  0
#  283               0                  0
#  ..              ...                ...
#  344               0                  0
#  345               0                  0
#  346               0                  0
#  347               0                  0
#  348               0                  0
#
#  [70 rows x 8 columns],
#  0      1
#  1      0
#  2      0
#  3      1
#  4      1
#        ..
#  274    0
#  275    0
#  276    0
#  277    0
#  278    0
#  Name: Outcome Variable, Length: 279, dtype: int64,
#  279    0
#  280    0
#  281    0
#  282    0
#  283    0
#        ..
#  344    1
#  345    1
#  346    1
#  347    1
#  348    1
#  Name: Outcome Variable, Length: 70, dtype: int64)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
model = LogisticRegression()

model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
score = accuracy_score(y_test, y_pred)

# %%
score
# Out:
# 0.6714285714285714
